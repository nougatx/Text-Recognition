# %%
#this uses pc camera
import cv2
import pytesseract

# Mention the installed location of Tesseract-OCR in your system
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Initialize the camera
cap = cv2.VideoCapture(0)  # 0 represents the default camera (usually the built-in webcam)

while True:
    # Read a frame from the camera
    ret, frame = cap.read()

    # Convert the frame to grayscale (optional but can improve OCR accuracy)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Perform text recognition on the frame
    text = pytesseract.image_to_string(gray)

    # Display the original frame with recognized text
    cv2.putText(frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.imshow('Text Recognition', frame)

    # Press 'q' to exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\Naseeba Rehman\Documents\GitHub\EPGxMoE\test2.ipynb Cell 1 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W0sZmlsZQ%3D%3D?line=20'>21</a> # Display the original frame with recognized text
#      <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W0sZmlsZQ%3D%3D?line=21'>22</a> cv2.putText(frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W0sZmlsZQ%3D%3D?line=22'>23</a> cv2.imshow('Text Recognition', frame)
#      <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W0sZmlsZQ%3D%3D?line=24'>25</a> # Press 'q' to exit the loop
#      <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a> if cv2.waitKey(1) & 0xFF == ord('q'):
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
#this uses phone cam
import cv2
import pytesseract

# Mention the installed location of Tesseract-OCR in your system
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

capture = cv2.VideoCapture('http://192.168.1.102:4747/video')

while True:
    ret, frame = capture.read()

    #Check if a frame was successfully captured
    if not ret:
        print("Failed to capture frame.")
        break

    #Check if the frame has valid dimensions
    if frame.shape[0] == 0 or frame.shape[1] == 0:
        print("Invalid frame dimensions.")
        break

    #Convert the frame to grayscale (optional but can improve OCR accuracy)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    #text recognition on the frame
    text = pytesseract.image_to_string(gray)
    #Display the original frame with recognized text
    cv2.putText(frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.imshow('Text Recognition', frame)

    # cv2.imshow('Camera Stream', frame)

    if cv2.waitKey(1) == ord('q'):
        break

capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\Naseeba Rehman\Documents\GitHub\EPGxMoE\test2.ipynb Cell 2 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W1sZmlsZQ%3D%3D?line=28'>29</a> # Display the original frame with recognized text
#      <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W1sZmlsZQ%3D%3D?line=29'>30</a> cv2.putText(frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W1sZmlsZQ%3D%3D?line=30'>31</a> cv2.imshow('Text Recognition', frame)
#      <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W1sZmlsZQ%3D%3D?line=32'>33</a> # cv2.imshow('Camera Stream', frame)
#      <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W1sZmlsZQ%3D%3D?line=34'>35</a> if cv2.waitKey(1) == ord('q'):
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
#make this code run faster?
import cv2
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'


cap = cv2.VideoCapture('http://10.10.177.91:4747/video')

while True:
    ret, frame = cap.read()
    frame = cv2.resize(frame, None, fx=0.5, fy=0.5)  # Resize the frame (adjust as needed)

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    text = pytesseract.image_to_string(gray)

    cv2.putText(frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.imshow('Text Recognition', frame)

    print(text)
    # if text == "Tuesday" or "tuesday":
    #     print(text)
    #     break
    # else: continue
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Tet: trend gap
# x
#
# Ras
#
#
# "Shy 6o
#
# Saran
#
# tle Hen teliag
# FP ple x
#
# ty
#
# Nes Aine
# Panes
#
# 1 Rerenyes

# %%
#supposedly faster by blackboxai
import cv2
import easyocr

reader = easyocr.Reader(['en'])

cap = cv2.VideoCapture('http://10.10.177.91:4747/video')

while True:
    ret, frame = cap.read()
    frame = cv2.resize(frame, None, fx=0.5, fy=0.5) # Resize the frame (adjust as needed)

    text = reader.readtext(frame)

    for detection in text:
        cv2.putText(frame, detection[1], (detection[0][0], detection[0][1]), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    cv2.imshow('Text Recognition', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Naseeba Rehman\Documents\GitHub\EPGxMoE\test2.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> #supposedly faster by blackboxai
#       <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> import cv2
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> import easyocr
#       <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> reader = easyocr.Reader(['en'])
#       <a href='vscode-notebook-cell:/c%3A/Users/Naseeba%20Rehman/Documents/GitHub/EPGxMoE/test2.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> cap = cv2.VideoCapture('http://10.10.177.91:4747/video')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\easyocr\__init__.py:1
# ----> 1 from .easyocr import Reader
#       3 __version__ = '1.7.1'
#
# File ~\AppData\Roaming\Python\Python311\site-packages\easyocr\easyocr.py:3
#       1 # -*- coding: utf-8 -*-
# ----> 3 from .recognition import get_recognizer, get_text
#       4 from .utils import group_text_box, get_image_list, calculate_md5, get_paragraph,\
#       5                    download_and_unzip, printProgressBar, diff, reformat_input,\
#       6                    make_rotated_img_list, set_result_with_confidence,\
#       7                    reformat_input_batched, merge_to_free
#       8 from .config import *
#
# File ~\AppData\Roaming\Python\Python311\site-packages\easyocr\recognition.py:10
#       8 from collections import OrderedDict
#       9 import importlib
# ---> 10 from .utils import CTCLabelConverter
#      11 import math
#      13 def custom_mean(x):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\easyocr\utils.py:9
#       7 import cv2
#       8 from PIL import Image, JpegImagePlugin
# ----> 9 from scipy import ndimage
#      10 import hashlib
#      11 import sys, os
#
# File <frozen importlib._bootstrap>:1231, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\__init__.py:217, in __getattr__(name)
#     215 def __getattr__(name):
#     216     if name in submodules:
# --> 217         return _importlib.import_module(f'scipy.{name}')
#     218     else:
#     219         try:
#
# File c:\Users\Naseeba Rehman\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\ndimage\__init__.py:154
#     152 from ._filters import *  # noqa: F401 F403
#     153 from ._fourier import *  # noqa: F401 F403
# --> 154 from ._interpolation import *  # noqa: F401 F403
#     155 from ._measurements import *  # noqa: F401 F403
#     156 from ._morphology import *  # noqa: F401 F403
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\ndimage\_interpolation.py:37
#      34 import numpy
#      35 from numpy.core.multiarray import normalize_axis_index
# ---> 37 from scipy import special
#      38 from . import _ni_support
#      39 from . import _nd_image
#
# File <frozen importlib._bootstrap>:1231, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\__init__.py:217, in __getattr__(name)
#     215 def __getattr__(name):
#     216     if name in submodules:
# --> 217         return _importlib.import_module(f'scipy.{name}')
#     218     else:
#     219         try:
#
# File c:\Users\Naseeba Rehman\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\special\__init__.py:671
#     667 from ._basic import *
#     669 from ._logsumexp import logsumexp, softmax, log_softmax
# --> 671 from . import _orthogonal
#     672 from ._orthogonal import *
#     674 from ._spfun_stats import multigammaln
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\special\_orthogonal.py:81
#      78 import numpy as np
#      79 from numpy import (exp, inf, pi, sqrt, floor, sin, cos, around,
#      80                    hstack, arccos, arange)
# ---> 81 from scipy import linalg
#      82 from scipy.special import airy
#      84 # Local imports.
#
# File <frozen importlib._bootstrap>:1231, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\__init__.py:217, in __getattr__(name)
#     215 def __getattr__(name):
#     216     if name in submodules:
# --> 217         return _importlib.import_module(f'scipy.{name}')
#     218     else:
#     219         try:
#
# File c:\Users\Naseeba Rehman\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\linalg\__init__.py:199
#     197 from ._misc import *
#     198 from ._cythonized_array_utils import *
# --> 199 from ._basic import *
#     200 from ._decomp import *
#     201 from ._decomp_lu import *
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1080, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1504, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1476, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1645, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:161, in _path_isfile(path)
#
# File <frozen importlib._bootstrap_external>:153, in _path_is_mode_type(path, mode)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:
